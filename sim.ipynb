# %%
# Out:
# Step 0 | EE Pos: [0.000, 0.000, 0.000] | Target Pos: [0.000, 0.000, 0.150] | Dist: 0.150 | Angle Diff: 120.00°
# Environment closed.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 21
#      19 if tick % 10 == 0:
#      20     p_cam, R_cam = env.get_camera_pose("cam2")  # replace "cam2" with your actual camera body name
# ---> 21     rgb, depth = env.render_egocentric_rgbd_image(p_cam, R_cam)
#      23     plt.figure(figsize=(10, 4))
#      25     plt.subplot(1, 2, 1)
#
# File c:\Users\ptfc0\Downloads\LabratoryPickNPlace-main\LabratoryPickNPlace-main\robot_env.py:121, in RobotEnv.render_egocentric_rgbd_image(self, p_cam, R_cam, width, height, fovy)
#     119 # Assign camera position, lookat, and up vectors element-wise
#     120 for i in range(3):
# --> 121     camera.pos[i] = p_cam[i]
# ...
